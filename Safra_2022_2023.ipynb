# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# Safra 2022/2023
safras = {
    'Cultura': ['Soja', 'Milho', 'Cana-de-açúcar', 'Café', 'Algodão', 'Arroz', 'Feijão', 'Trigo'],
    'Produção (milhões de toneladas)': [135, 120, 630, 60, 2.7, 11, 3.3, 9.5],
    'Mato Grosso': [35, 40, 30, 0, 1.8, 0.1, 0.3, 0],
    'Paraná': [19, 32, 30, 0.5, 0, 0.2, 1.0, 4.5],
    'Rio Grande do Sul': [20, 25, 60, 0.5, 0, 8.2, 0.2, 3.5],
    'Goiás': [15, 25, 60, 0.1, 0.5, 0.2, 0.8, 0.5],
    'Minas Gerais': [12, 10, 50, 27, 0.2, 0.1, 0.7, 0.5],
    'São Paulo': [10, 5, 170, 5, 0.1, 0.1, 0.3, 0.5],
    'Bahia': [8, 8, 15, 1, 0.1, 0.1, 0.4, 0],
    'Mato Grosso do Sul': [10, 10, 40, 0, 0.1, 0.1, 0.2, 0.5],
    'Espírito Santo': [0, 0, 0, 9, 0, 0, 0, 0],
    'Santa Catarina': [1, 2, 0, 0, 0, 2.5, 0.1, 0.5],
    'Rondônia': [0, 0, 0, 1, 0, 0, 0, 0],
    'Tocantins': [0, 0, 0, 0, 0, 0.5, 0.1, 0],
    'Maranhão': [5, 3, 0, 0, 0, 0.2, 0.1, 0]
}

# %%
# df
df = pd.DataFrame(data)
df
# Out:
#           Cultura  Produção (milhões de toneladas)  Mato Grosso  Paraná  \
# 0            Soja                            135.0         35.0    19.0
# 1           Milho                            120.0         40.0    32.0
# 2  Cana-de-açúcar                            630.0         30.0    30.0
# 3            Café                             60.0          0.0     0.5
# 4         Algodão                              2.7          1.8     0.0
# 5           Arroz                             11.0          0.1     0.2
# 6          Feijão                              3.3          0.3     1.0
# 7           Trigo                              9.5          0.0     4.5
#
#    Rio Grande do Sul  Goiás  Minas Gerais  São Paulo  Bahia  \
# 0               20.0   15.0          12.0       10.0    8.0
# 1               25.0   25.0          10.0        5.0    8.0
# 2               60.0   60.0          50.0      170.0   15.0
# 3                0.5    0.1          27.0        5.0    1.0
# ...

# %%
# Comentário referenciando as fontes oficiais
# Fontes dos dados:
# - Companhia Nacional de Abastecimento (CONAB). (2023). Acompanhamento da Safra Brasileira de Grãos. Disponível em: https://www.conab.gov.br
# - Instituto Brasileiro de Geografia e Estatística (IBGE). (2023). Produção Agrícola Municipal (PAM). Disponível em: https://www.ibge.gov.br
# - Ministério da Agricultura, Pecuária e Abastecimento (MAPA). (2023). Anuário Estatístico da Agricultura. Disponível em: https://www.gov.br/agricultura/pt-br

# %%
# Produção culturas - Safra 2022/2023
figsize = (12, 1.2 * len(df['Cultura'].unique()))

plt.figure(figsize=figsize)
sns.barplot(df, x='Produção (milhões de toneladas)', y='Cultura')
sns.despine(top=True, right=True, bottom=True, left=True)
